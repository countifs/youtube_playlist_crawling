# %% [markdown]
# <a href="https://colab.research.google.com/github/countifs/youtube_playlist_crawling/blob/main/%EC%9C%A0%ED%8A%9C%EB%B8%8C_%EC%9E%AC%EC%83%9D%EB%AA%A9%EB%A1%9D_%ED%81%AC%EB%A1%A4%EB%A7%81(%EA%B5%AC%EA%B8%80%EC%BD%94%EB%9E%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **유튜브 재생목록 크롤링 (구글코랩)**

# %%
# url 주소 입력
url = input('>> URL 주소를 입력 : ')

# 재생목록 제목에서 제거할 텍스트(문자)를 입력
rep_text  = input('>> 제거할 텍스트를 입력하세요 : ')

# 모듈 설치하기
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver

# 웹 브라우저 작동을 위한 라이브러리
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys

# 웹브라우저 작동을 기다리기 위한 라이브러리
import time
import random

# 시간 관련 라이브러리
from datetime import datetime, timedelta
from pytz import timezone

# IPython
from IPython.display import display

# 경고 무시
import warnings
warnings.filterwarnings(action='ignore')

# 데이터프레임 및 CSV 파일 저장을 위한 라이브러리
import pandas as pd

# 데이터프레임 출력
from tabulate import tabulate

# 크롬드라이버 option설정
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

def get_playlist(url, rep_text):

    # 브라우저 생성
    driver = webdriver.Chrome('chromedriver', options=options)

    # 웹사이트 열기
    driver.get(url)

    # 로딩이 끝날 때까지 2초 정도 기다림
    driver.implicitly_wait(2)

   # 안정적인 페이지 소스 추출을 위해 3초 정도 기다림
    time.sleep(3)

    # 페이지 소스 추출
    html_source = driver.page_source
    soup_source = BeautifulSoup(html_source, 'lxml')

    # 파싱정보 가져오기
    parsing = soup_source.find_all('a', class_ = 'yt-simple-endpoint style-scope ytd-playlist-video-renderer')
    video_time = soup_source.find_all('span', class_ ='style-scope ytd-thumbnail-overlay-time-status-renderer') #검색했을 때 검색숫자가 안맞아서 확인이 필요함

    # 파싱정보 정리하기
    name_list = []
    url_list = []
    time_list = []

    for i in range(len(parsing)):
        name_list.append(parsing[i].text.strip())
        main = 'https://www.youtube.com'
        sub = parsing[i].get('href')  
        url_list.append(f'{main}{sub}')
        time_list.append(video_time[i].text.strip())

   # 출력용 데이터 프레임 구성하기     
    playlist = {
        '시간' : time_list,
        '확인' : '',    
        'No' : range(1, len(parsing)+1),
        'URL' : url_list, 
    }

   # 데이터 프레임 생성
    name_list = pd.Series(name_list)

   # 제목에서 제거할 문자 변환하기
    name_list = name_list.apply(lambda x: x.replace(rep_text,'').strip())
    playlist = pd.DataFrame(playlist, index = name_list)

    return playlist

get_playlist(url, rep_text)
# Out:
# >> URL 주소를 입력 : https://www.youtube.com/playlist?list=PL0lkHWVqBqedhxRc4U9AND0_hKOI7PhoL
# >> 제거할 텍스트를 입력하세요 :
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.8/dist-packages (4.7.2)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.9.24)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.8/dist-packages (from selenium) (1.26.13)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.8/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 261 kB in 3s (87.0 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (107.0.5304.87-0ubuntu11.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
#                                                        시간 확인  No  \
# 이제 비전문가도 AutoML 써요.. 코딩 없이 H2O AutoML을 손쉽게 사용해보...   7:30      1
# 🔥영상 하나로 KNIME 사용법 완벽 정리🔥 나임을 활용한 데이터 전처리 방법 [KN...  59:27      2
# 전문가와 함께하는 KNIME 기능 소개 6강 : 데이터 사이언스 소개 part 2       17:44      3
# 전문가와 함께하는 KNIME 기능 소개 5강 : 데이터 사이언스 소개 part 1       15:36      4
# 전문가와 함께하는 KNIME 기능 소개 4강 : 빅데이터 처리 (Big Data Pr...  13:23      5
# 전문가와 함께하는 KNIME 기능 소개 3강 : 데이터 클리닝 (Data Cleaning)  15:00      6
# 전문가와 함께하는 KNIME 기능 소개 2강 : 데이터 전처리 (Data Manipu...   9:43      7
# 전문가와 함께하는 KNIME 기능 소개 1강 : 데이터 집계 (Data Aggrega...   9:13      8
#
#                                                                                                   URL
# 이제 비전문가도 AutoML 써요.. 코딩 없이 H2O AutoML을 손쉽게 사용해보...  https://www.youtube.com/watch?v=zINiRlYqfKQ&li...
# 🔥영상 하나로 KNIME 사용법 완벽 정리🔥 나임을 활용한 데이터 전처리 방법 [KN...  https://www.youtube.com/watch?v=YxADOc90hlM&li...
# 전문가와 함께하는 KNIME 기능 소개 6강 : 데이터 사이언스 소개 part 2       https://www.youtube.com/watch?v=jOY5mz1IJ0s&li...
# 전문가와 함께하는 KNIME 기능 소개 5강 : 데이터 사이언스 소개 part 1       https://www.youtube.com/watch?v=YVt20zoOvjs&li...
# 전문가와 함께하는 KNIME 기능 소개 4강 : 빅데이터 처리 (Big Data Pr...  https://www.youtube.com/watch?v=XA8qDEOXyfA&li...
# 전문가와 함께하는 KNIME 기능 소개 3강 : 데이터 클리닝 (Data Cleaning)  https://www.youtube.com/watch?v=ADcz4ENVQME&li...
# 전문가와 함께하는 KNIME 기능 소개 2강 : 데이터 전처리 (Data Manipu...  https://www.youtube.com/watch?v=3COnNsJpVRE&li...
# 전문가와 함께하는 KNIME 기능 소개 1강 : 데이터 집계 (Data Aggrega...  https://www.youtube.com/watch?v=FFfvy0_JNs0&li...

# %%
get_playlist(url, rep_text).sort_index()
# Out:
#                                                        시간 확인  No  \
# 1-1. 머신러닝 개요                                        31:58      1
# 1-2  머신러닝 분류 및 주의사항                                 49:26      2
# 2-1.  Scikit learn 소개                               28:24      3
# 2-2. IRIS 붓꽃 품종 예측 실습                               30:14      4
# 3-1. 교차검증                                           24:14      5
# 3-2. 하이퍼파라미터튜닝                                      22:04      6
# 3-3. scikit-learn - preprocessing 모듈                45:28     24
# 4-1.  분류(Classification) - 결정트리                     48:13      7
# 4-2.   결정트리 하이퍼파라미터 소개 및 사용 팁                       23:05      8
# 5-1.  결정트리 실습 : 타이타닉 생존자 예측 분류                      44:29      9
# 5-2. 결정트리 시각화 실습   타이타닉 생존자 예측 모델                   17:24     10
# 6-1.  앙상블(Ensemble) - Voting                        26:40     11
# 6-2.  앙상블(Ensemble) Bagging (feat.  랜덤포레스트)         35:47     12
# 6-3. 앙상블(Ensemble) : Boosting                       26:39     13
# 6-4. 앙상블(Ensemble) XGBoost의 이해                      35:40     14
# 6-5.  앙상블(Ensemble) : GBM&XGBoost 실습                14:09     15
# 7-1. 신용카드 사기 검출 실습 1: 데이터 탐색 및 전처리                  17:58     16
# 7-2. 신용카드 사기 검출 실습 2: 분류 평가 지표(accuracy, precis...  23:51     17
# 7-3. 신용카드 사기 검출 실습 3 : 아웃라이어 제거하기                   11:49     18
# 7-4. 신용카드 사기 검출 실습 4:  샘플링(SMOTE for 불균형 데이터 처리)    15:13     19
# 8-1. 회귀(Regression)                                 14:47     20
# 8-2. 캘리포니아주택가격 예측 회귀(Regression 실습 1):  데이터적재및탐색    19:49     21
# 8-3.  캘리포니아주택가격 예측 회귀(Regression 실습 2):  데이터전처리     29:14     22
# 8-4. 캘리포니아주택가격 예측 회귀(Regression 실습 3)  모델학습 및 평가    28:15     23
#
#                                                                                                   URL
# 1-1. 머신러닝 개요                                        https://www.youtube.com/watch?v=mn4aTKsSnFg&li...
# 1-2  머신러닝 분류 및 주의사항                                 https://www.youtube.com/watch?v=jfVAjx0dHa8&li...
# 2-1.  Scikit learn 소개                               https://www.youtube.com/watch?v=lZjbqfFjpM0&li...
# 2-2. IRIS 붓꽃 품종 예측 실습                               https://www.youtube.com/watch?v=3yEzwaGx9eo&li...
# 3-1. 교차검증                                           https://www.youtube.com/watch?v=gZhjgmQ0Dv4&li...
# 3-2. 하이퍼파라미터튜닝                                      https://www.youtube.com/watch?v=O1tCS7F8Bvs&li...
# 3-3. scikit-learn - preprocessing 모듈                https://www.youtube.com/watch?v=KRRxLhBve7k&li...
# 4-1.  분류(Classification) - 결정트리                     https://www.youtube.com/watch?v=8KgqcWLit2E&li...
# 4-2.   결정트리 하이퍼파라미터 소개 및 사용 팁                       https://www.youtube.com/watch?v=kcMI1j_xff0&li...
# 5-1.  결정트리 실습 : 타이타닉 생존자 예측 분류                      https://www.youtube.com/watch?v=o2_Xsbyhxf4&li...
# 5-2. 결정트리 시각화 실습   타이타닉 생존자 예측 모델                   https://www.youtube.com/watch?v=Enbi5vNnP_E&li...
# 6-1.  앙상블(Ensemble) - Voting                        https://www.youtube.com/watch?v=b6uq0dB35Z0&li...
# 6-2.  앙상블(Ensemble) Bagging (feat.  랜덤포레스트)         https://www.youtube.com/watch?v=iFhgg-AsYEM&li...
# 6-3. 앙상블(Ensemble) : Boosting                       https://www.youtube.com/watch?v=OYepi-9jTg0&li...
# 6-4. 앙상블(Ensemble) XGBoost의 이해                      https://www.youtube.com/watch?v=iKF-qR4Fzh4&li...
# 6-5.  앙상블(Ensemble) : GBM&XGBoost 실습                https://www.youtube.com/watch?v=THRAvXS7TT8&li...
# 7-1. 신용카드 사기 검출 실습 1: 데이터 탐색 및 전처리                  https://www.youtube.com/watch?v=t1SdIbV0GxY&li...
# 7-2. 신용카드 사기 검출 실습 2: 분류 평가 지표(accuracy, precis...  https://www.youtube.com/watch?v=xtpffUWlvGk&li...
# 7-3. 신용카드 사기 검출 실습 3 : 아웃라이어 제거하기                   https://www.youtube.com/watch?v=w8kB4JuIEWo&li...
# 7-4. 신용카드 사기 검출 실습 4:  샘플링(SMOTE for 불균형 데이터 처리)    https://www.youtube.com/watch?v=DmWw9P-cZPM&li...
# 8-1. 회귀(Regression)                                 https://www.youtube.com/watch?v=JB384Vyk31A&li...
# 8-2. 캘리포니아주택가격 예측 회귀(Regression 실습 1):  데이터적재및탐색    https://www.youtube.com/watch?v=MJLMhrsxpwY&li...
# 8-3.  캘리포니아주택가격 예측 회귀(Regression 실습 2):  데이터전처리     https://www.youtube.com/watch?v=sHIgqR7Dp34&li...
# 8-4. 캘리포니아주택가격 예측 회귀(Regression 실습 3)  모델학습 및 평가    https://www.youtube.com/watch?v=Jf-l9J5V-9o&li...

# %%
# url 주소 입력
url = input('>> URL 주소를 입력 : ')

# 재생목록 제목에서 제거할 텍스트(문자)를 입력
rep_text  = input('>> 제거할 텍스트를 입력하세요 : ')

get_playlist(url, rep_text)
# Out:
# >> URL 주소를 입력 : https://www.youtube.com/playlist?list=PLXDcZE7KzqCunKwuHfbHcKADVqMoGLAzX
# >> 제거할 텍스트를 입력하세요 : #
#                                                        시간 확인  No  \
# #1-1. 머신러닝 개요                                       31:58      1
# #1-2  머신러닝 분류 및 주의사항                                49:26      2
# #2-1.  Scikit learn 소개                              28:24      3
# #2-2. IRIS 붓꽃 품종 예측 실습                              30:14      4
# #3-1. 교차검증                                          24:14      5
# #3-2. 하이퍼파라미터튜닝                                     22:04      6
# #4-1.  분류(Classification) - 결정트리                    48:13      7
# #4-2.   결정트리 하이퍼파라미터 소개 및 사용 팁                      23:05      8
# #5-1.  결정트리 실습 : 타이타닉 생존자 예측 분류                     44:29      9
# #5-2. 결정트리 시각화 실습   타이타닉 생존자 예측 모델                  17:24     10
# #6-1.  앙상블(Ensemble) - Voting                       26:40     11
# #6-2.  앙상블(Ensemble) Bagging (feat.  랜덤포레스트)        35:47     12
# #6-3. 앙상블(Ensemble) : Boosting                      26:39     13
# #6-4. 앙상블(Ensemble) XGBoost의 이해                     35:40     14
# #6-5.  앙상블(Ensemble) : GBM&XGBoost 실습               14:09     15
# #7-1. 신용카드 사기 검출 실습 1: 데이터 탐색 및 전처리                 17:58     16
# #7-2. 신용카드 사기 검출 실습 2: 분류 평가 지표(accuracy, preci...  23:51     17
# #7-3. 신용카드 사기 검출 실습 3 : 아웃라이어 제거하기                  11:49     18
# #7-4. 신용카드 사기 검출 실습 4:  샘플링(SMOTE for 불균형 데이터 처리)   15:13     19
# #8-1. 회귀(Regression)                                14:47     20
# #8-2. 캘리포니아주택가격 예측 회귀(Regression 실습 1):  데이터적재및탐색   19:49     21
# #8-3.  캘리포니아주택가격 예측 회귀(Regression 실습 2):  데이터전처리    29:14     22
# #8-4. 캘리포니아주택가격 예측 회귀(Regression 실습 3)  모델학습 및 평가   28:15     23
# #3-3. scikit-learn - preprocessing 모듈               45:28     24
#
#                                                                                                   URL
# #1-1. 머신러닝 개요                                       https://www.youtube.com/watch?v=mn4aTKsSnFg&li...
# #1-2  머신러닝 분류 및 주의사항                                https://www.youtube.com/watch?v=jfVAjx0dHa8&li...
# #2-1.  Scikit learn 소개                              https://www.youtube.com/watch?v=lZjbqfFjpM0&li...
# #2-2. IRIS 붓꽃 품종 예측 실습                              https://www.youtube.com/watch?v=3yEzwaGx9eo&li...
# #3-1. 교차검증                                          https://www.youtube.com/watch?v=gZhjgmQ0Dv4&li...
# #3-2. 하이퍼파라미터튜닝                                     https://www.youtube.com/watch?v=O1tCS7F8Bvs&li...
# #4-1.  분류(Classification) - 결정트리                    https://www.youtube.com/watch?v=8KgqcWLit2E&li...
# #4-2.   결정트리 하이퍼파라미터 소개 및 사용 팁                      https://www.youtube.com/watch?v=kcMI1j_xff0&li...
# #5-1.  결정트리 실습 : 타이타닉 생존자 예측 분류                     https://www.youtube.com/watch?v=o2_Xsbyhxf4&li...
# #5-2. 결정트리 시각화 실습   타이타닉 생존자 예측 모델                  https://www.youtube.com/watch?v=Enbi5vNnP_E&li...
# #6-1.  앙상블(Ensemble) - Voting                       https://www.youtube.com/watch?v=b6uq0dB35Z0&li...
# #6-2.  앙상블(Ensemble) Bagging (feat.  랜덤포레스트)        https://www.youtube.com/watch?v=iFhgg-AsYEM&li...
# #6-3. 앙상블(Ensemble) : Boosting                      https://www.youtube.com/watch?v=OYepi-9jTg0&li...
# #6-4. 앙상블(Ensemble) XGBoost의 이해                     https://www.youtube.com/watch?v=iKF-qR4Fzh4&li...
# #6-5.  앙상블(Ensemble) : GBM&XGBoost 실습               https://www.youtube.com/watch?v=THRAvXS7TT8&li...
# #7-1. 신용카드 사기 검출 실습 1: 데이터 탐색 및 전처리                 https://www.youtube.com/watch?v=t1SdIbV0GxY&li...
# #7-2. 신용카드 사기 검출 실습 2: 분류 평가 지표(accuracy, preci...  https://www.youtube.com/watch?v=xtpffUWlvGk&li...
# #7-3. 신용카드 사기 검출 실습 3 : 아웃라이어 제거하기                  https://www.youtube.com/watch?v=w8kB4JuIEWo&li...
# #7-4. 신용카드 사기 검출 실습 4:  샘플링(SMOTE for 불균형 데이터 처리)   https://www.youtube.com/watch?v=DmWw9P-cZPM&li...
# #8-1. 회귀(Regression)                                https://www.youtube.com/watch?v=JB384Vyk31A&li...
# #8-2. 캘리포니아주택가격 예측 회귀(Regression 실습 1):  데이터적재및탐색   https://www.youtube.com/watch?v=MJLMhrsxpwY&li...
# #8-3.  캘리포니아주택가격 예측 회귀(Regression 실습 2):  데이터전처리    https://www.youtube.com/watch?v=sHIgqR7Dp34&li...
# #8-4. 캘리포니아주택가격 예측 회귀(Regression 실습 3)  모델학습 및 평가   https://www.youtube.com/watch?v=Jf-l9J5V-9o&li...
# #3-3. scikit-learn - preprocessing 모듈               https://www.youtube.com/watch?v=KRRxLhBve7k&li...
