# %% [markdown]
# <a href="https://colab.research.google.com/github/countifs/youtube_playlist_crawling/blob/main/%EC%9C%A0%ED%8A%9C%EB%B8%8C_%EC%9E%AC%EC%83%9D%EB%AA%A9%EB%A1%9D_%ED%81%AC%EB%A1%A4%EB%A7%81(%EA%B5%AC%EA%B8%80%EC%BD%94%EB%9E%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# url 주소 입력
url = input('>> URL 주소를 입력 : ')

# 재생목록 제목에서 제거할 텍스트(문자)를 입력
rep_text  = input('>> 제거할 텍스트를 입력하세요 : ')

# 모듈 설치하기
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver

# 웹 브라우저 작동을 위한 라이브러리
from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys

# 웹브라우저 작동을 기다리기 위한 라이브러리
import time
import random

# 시간 관련 라이브러리
from datetime import datetime, timedelta
from pytz import timezone

# IPython
from IPython.display import display

# 경고 무시
import warnings
warnings.filterwarnings(action='ignore')

# 데이터프레임 및 CSV 파일 저장을 위한 라이브러리
import pandas as pd

# 데이터프레임 출력
from tabulate import tabulate

# 크롬드라이버 option설정
options = webdriver.ChromeOptions()
options.add_argument('--headless')        # Head-less 설정
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

def get_playlist(url, rep_text):

    # 브라우저 생성
    driver = webdriver.Chrome('chromedriver', options=options)

    # 웹사이트 열기
    driver.get(url)

    # 로딩이 끝날 때까지 3초 정도 기다림
    driver.implicitly_wait(3)

    time.sleep(4)

    # 페이지 소스 추출
    html_source = driver.page_source
    soup_source = BeautifulSoup(html_source, 'lxml')

    # 파싱정보 가져오기
    parsing = soup_source.find_all('a', class_ = 'yt-simple-endpoint style-scope ytd-playlist-video-renderer')
    video_time = soup_source.find_all('span', class_ ='style-scope ytd-thumbnail-overlay-time-status-renderer') #검색했을 때 검색숫자가 안맞아서 확인이 필요함

    # 파싱정보 정리하기
    name_list = []
    url_list = []
    time_list = []

    for i in range(len(parsing)):
        name_list.append(parsing[i].text.strip())
        main = 'https://www.youtube.com'
        sub = parsing[i].get('href')  
        url_list.append(f'{main}{sub}')
        time_list.append(video_time[i].text.strip())

        
    playlist = {
        '시간' : time_list,
        '확인' : '',    
        'No' : range(1, len(parsing)+1),
        'URL' : url_list, 
    }

    name_list = pd.Series(name_list)
    name_list.apply(lambda x: x.replace(rep_text,'').strip())
    playlist = pd.DataFrame(playlist, index = name_list)

    return playlist

get_playlist(url, rep_text)
# Out:
# >> URL 주소를 입력 : https://www.youtube.com/playlist?list=PLrpXwtuxGqcIIf_SpCWg04MoHf1yJUCvi
# >> 제거할 텍스트를 입력하세요 :
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.7.2-py3-none-any.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 6.1 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.9.24)
# Collecting urllib3[socks]~=1.26
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 47.1 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      |████████████████████████████████| 384 kB 12.2 MB/s
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.1.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.4 MB/s
# Installing collected packages: sniffio, outcome, h11, exceptiongroup, async-generator, wsproto, urllib3, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.13 which is incompatible.
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.7.2 sniffio-1.3.0 trio-0.22.0 trio-websocket-0.9.2 urllib3-1.26.13 wsproto-1.2.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,307 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.9 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,227 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,348 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,519 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,140 kB]
# Get:21 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [40.8 kB]
# Fetched 9,935 kB in 4s (2,336 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 7 not upgraded.
# Need to get 95.1 MB of archives.
# After this operation, 319 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 107.0.5304.87-0ubuntu11.18.04.1 [1,158 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 107.0.5304.87-0ubuntu11.18.04.1 [83.1 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 107.0.5304.87-0ubuntu11.18.04.1 [5,260 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 107.0.5304.87-0ubuntu11.18.04.1 [5,570 kB]
# Fetched 95.1 MB in 3s (29.9 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 124015 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_107.0.5304.87-0ubuntu11.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_107.0.5304.87-0ubuntu11.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser (107.0.5304.87-0ubuntu11.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (107.0.5304.87-0ubuntu11.18.04.1) ...
# Setting up chromium-browser-l10n (107.0.5304.87-0ubuntu11.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
#                                           시간 확인  No  \
# 데이터프레임이란? | 판다스 사전강의                   11:45      1
# 인덱싱과 슬라이싱 | 판다스 기본강의 #01                9:04      2
# sort_values : 정렬 | 판다스 기본강의 #02         3:16      3
# broadcasting과 연산 | 판다스 기본강의 #03         5:43      4
# boolean indexing | 판다스 기본강의 #04         8:19      5
# index & columns | 판다스 기본강의 #05         14:18      6
# pivot & pivot_table | 판다스 기본강의 #06     11:24      7
# unpivot | 판다스 기본강의 #07                 17:30      8
# concat | 판다스 기본강의 #08                   8:23      9
# value_counts | 판다스 기본강의 #09             6:54     10
# 중복 데이터 처리 | 판다스 기본강의 #10                6:55     11
# merge | 판다스 기본강의 #11                   15:46     12
# merge_asof | 판다스 기본강의 #12              14:22     13
# 열(column) | 판다스 기본강의 #13               11:15     14
# rank | 판다스 기본강의 #14                     8:57     15
# boolean masking | 판다스 기본강의 #15         15:01     16
# apply | 판다스 기본강의 #16                   21:00     17
# map, apply, applymap의 차이 | 판다스특강 #01   13:16     18
# agg | 판다스 기본강의 #17                     16:49     19
# groupby로 그룹집계 | 판다스 기본강의 #18           16:06     20
# groupby와 pivot_table 비교하기 | 판다스특강 #02  14:00     21
# groupby로 열만들기 | 판다스 기본강의 #19           11:41     22
# groupby로 동명이인 구분하기 | 판다스특강 #03          9:37     23
# groupby + transform | 판다스 기본강의 #20     11:37     24
# shift | 판다스 기본강의 #21                   10:08     25
# 근사값 VLOOKUP  |  판다스 특강 #04             13:13     26
# lambda함수에 index 정보 사용하기 | 판다스특강 #04     5:06     27
# to_numeric과 astype의 차이 | 판다스특강 #05      8:00     28
# 순서대로 특정 값을 기준으로 그룹부여하기 | 판다스특강 #06      4:13     29
#
#                                                                                      URL
# 데이터프레임이란? | 판다스 사전강의                   https://www.youtube.com/watch?v=SVjKsvvhWlQ&li...
# 인덱싱과 슬라이싱 | 판다스 기본강의 #01               https://www.youtube.com/watch?v=W2KYhekdtfU&li...
# sort_values : 정렬 | 판다스 기본강의 #02        https://www.youtube.com/watch?v=63eJ2izsFus&li...
# broadcasting과 연산 | 판다스 기본강의 #03        https://www.youtube.com/watch?v=iZ6v1DSmrHU&li...
# boolean indexing | 판다스 기본강의 #04        https://www.youtube.com/watch?v=poaOpqec8ho&li...
# index & columns | 판다스 기본강의 #05         https://www.youtube.com/watch?v=sKtMAVnpHHs&li...
# pivot & pivot_table | 판다스 기본강의 #06     https://www.youtube.com/watch?v=6KO0F1NJlmc&li...
# unpivot | 판다스 기본강의 #07                 https://www.youtube.com/watch?v=dhqkwebrVFQ&li...
# concat | 판다스 기본강의 #08                  https://www.youtube.com/watch?v=MiK2K-UdtZk&li...
# value_counts | 판다스 기본강의 #09            https://www.youtube.com/watch?v=OGhMUgXSnCs&li...
# 중복 데이터 처리 | 판다스 기본강의 #10               https://www.youtube.com/watch?v=qiRmaWCCgBE&li...
# merge | 판다스 기본강의 #11                   https://www.youtube.com/watch?v=7bc04EbPtcE&li...
# merge_asof | 판다스 기본강의 #12              https://www.youtube.com/watch?v=jpeByULxoYw&li...
# 열(column) | 판다스 기본강의 #13               https://www.youtube.com/watch?v=32ibROxrS3Y&li...
# rank | 판다스 기본강의 #14                    https://www.youtube.com/watch?v=ooMCVlXCdNU&li...
# boolean masking | 판다스 기본강의 #15         https://www.youtube.com/watch?v=_5KaKUfCWm4&li...
# apply | 판다스 기본강의 #16                   https://www.youtube.com/watch?v=vsEA9eFvdQY&li...
# map, apply, applymap의 차이 | 판다스특강 #01   https://www.youtube.com/watch?v=upY7WRenFjo&li...
# agg | 판다스 기본강의 #17                     https://www.youtube.com/watch?v=5YYkvM9I36E&li...
# groupby로 그룹집계 | 판다스 기본강의 #18           https://www.youtube.com/watch?v=14p0QUgT_lo&li...
# groupby와 pivot_table 비교하기 | 판다스특강 #02  https://www.youtube.com/watch?v=YKojgvNC_Os&li...
# groupby로 열만들기 | 판다스 기본강의 #19           https://www.youtube.com/watch?v=7qu2Ua1bYvM&li...
# groupby로 동명이인 구분하기 | 판다스특강 #03         https://www.youtube.com/watch?v=_HEsUPZOeHw&li...
# groupby + transform | 판다스 기본강의 #20     https://www.youtube.com/watch?v=N63UkVC_Si8&li...
# shift | 판다스 기본강의 #21                   https://www.youtube.com/watch?v=aXCf2pKT9xA&li...
# 근사값 VLOOKUP  |  판다스 특강 #04             https://www.youtube.com/watch?v=Fmaaa9hKnGA&li...
# lambda함수에 index 정보 사용하기 | 판다스특강 #04    https://www.youtube.com/watch?v=Tvcx4dAu_Ds&li...
# to_numeric과 astype의 차이 | 판다스특강 #05     https://www.youtube.com/watch?v=YhsSVDeLbTs&li...
# 순서대로 특정 값을 기준으로 그룹부여하기 | 판다스특강 #06     https://www.youtube.com/watch?v=z8jvDUhP0iE&li...

# %%
# url 주소 입력
url = input('>> URL 주소를 입력 : ')

# 재생목록 제목에서 제거할 텍스트(문자)를 입력
rep_text  = input('>> 제거할 텍스트를 입력하세요 : ')

get_playlist(url, rep_text)
# Out:
# >> URL 주소를 입력 : https://www.youtube.com/playlist?list=PLrpXwtuxGqcKe5T8FB2h3cjLOjplFS83h
# >> 제거할 텍스트를 입력하세요 :
#                                            시간 확인  No  \
# 인덱싱과 슬라이싱 | 판다스 실습강의 #01                 5:19      1
# sort_values : 정렬 | 판다스 실습강의 #02          5:55      2
# broadcasting과 연산 | 판다스 실습강의 #03          5:08      3
# boolean indexing | 판다스 실습강의 #04          8:44      4
# index & columns | 판다스 실습강의 #05           7:49      5
# 타이타닉생존자 통계  pivot_table | 판다스 실습강의 #06  12:20      6
# 월드컵자료 unpivot | 판다스 실습강의 #07            13:14      7
# concat | 판다스 실습강의 #08                   10:11      8
# 중복 데이터 처리 |  판다스 실습강의 #09                7:07      9
# merge |  판다스 실습강의 #10                    8:16     10
# rank  |  판다스 실습강의 #11                    9:35     11
# apply  |  판다스 실습강의 #12                  14:28     12
# groupby로 그룹집계  |  판다스 실습강의 #13           7:06     13
# groupby + transform  |  판다스 실습강의 #14     9:25     14
# shift  |  판다스 실습강의 #15                   8:06     15
#
#                                                                                       URL
# 인덱싱과 슬라이싱 | 판다스 실습강의 #01                https://www.youtube.com/watch?v=ZTZE_ze415o&li...
# sort_values : 정렬 | 판다스 실습강의 #02         https://www.youtube.com/watch?v=GEzBvSC7eHY&li...
# broadcasting과 연산 | 판다스 실습강의 #03         https://www.youtube.com/watch?v=337DhJ4rHlk&li...
# boolean indexing | 판다스 실습강의 #04         https://www.youtube.com/watch?v=hiGV8w_WhjI&li...
# index & columns | 판다스 실습강의 #05          https://www.youtube.com/watch?v=NnYqhNgN7-E&li...
# 타이타닉생존자 통계  pivot_table | 판다스 실습강의 #06  https://www.youtube.com/watch?v=yG68W6lCZHk&li...
# 월드컵자료 unpivot | 판다스 실습강의 #07            https://www.youtube.com/watch?v=OBmJ-69NSGo&li...
# concat | 판다스 실습강의 #08                   https://www.youtube.com/watch?v=UyyBU7Q0pjs&li...
# 중복 데이터 처리 |  판다스 실습강의 #09               https://www.youtube.com/watch?v=LM0flt1IR6s&li...
# merge |  판다스 실습강의 #10                   https://www.youtube.com/watch?v=5wgj3_ioGtY&li...
# rank  |  판다스 실습강의 #11                   https://www.youtube.com/watch?v=crMz5AmpPMU&li...
# apply  |  판다스 실습강의 #12                  https://www.youtube.com/watch?v=0xALwjLBEdA&li...
# groupby로 그룹집계  |  판다스 실습강의 #13          https://www.youtube.com/watch?v=QqRnOGjAHH0&li...
# groupby + transform  |  판다스 실습강의 #14    https://www.youtube.com/watch?v=UooZCxGOTak&li...
# shift  |  판다스 실습강의 #15                  https://www.youtube.com/watch?v=U-mUjHPp-S0&li...
